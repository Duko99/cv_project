# %% [markdown]
# # EfficientNetB0
# * source: https://keras.io/api/applications/#usage-examples-for-image-classification-models, https://keras.io/api/applications/efficientnet/
# * the B0 variant was chosen as it accepts images with 224 resolution, which is what the processing functions already scale the data to

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras import layers
from keras.models import Model, load_model
from keras.optimizers import Nadam
from numba import cuda  # https://stackoverflow.com/a/52354865/6476994
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from datetime import datetime
import keras
import tensorflow as tf

# %%
# allows all images to be displayed at once (else only displays the last call to plt.imshow())
# https://stackoverflow.com/a/41210974
def displayImage(image, caption = None, colour = None) -> None:
    plt.figure()
    if(colour != None):
        plt.imshow(image, cmap=colour)
    else:
        plt.imshow(image)
        
    if(caption != None):
        # display caption below picture (https://stackoverflow.com/a/51486361)
        plt.figtext(0.5, 0.01, caption, wrap=True, horizontalalignment='center', fontsize=12)

# %%
# free up GPU if it didn't after the last run
cuda.select_device(0)
cuda.close()

# %% [markdown]
# ## Read in dataset

# %% [markdown]
# * first argument is the `using_batch_generator` flag
# * second argument is `do_preprocessing`, which will perform image manipulations for the purposes of enhancing training performance
# * all other arguments are the datasets - e.g., a folder ('20160724_July') with additional folders ('BB01', 'BB02', ..., 'BBXY'), each containing a set of images)

# %%
# %run readInDataset.py false false 20160724_July 20160829_August
# %run readInDataset.py true false 20160724_July
# Out:
# args: ['readInDataset.py', 'true', 'false', '20160724_July']
# using_batch_generator? True
# doing pre-processing? False
# dataset_names: ['20160724_July']
# reading in images and labels for dataset: 20160724_July
# all_folders_for_curr_dataset: ['BB01', 'BB02', 'BB03', 'BB04', 'BB05', 'BB06', 'BB07', 'BB08', 'BB09', 'BB10', 'BB11', 'BB12', 'BB13', 'BB14', 'BB15', 'BB16', 'BB17', 'BB18', 'BB19', 'BB20', 'BB21', 'BB22', 'BB23', 'BB24', 'BB25', 'BB26', 'BB27', 'BB28', 'BB29', 'BB30', 'BB31', 'BB32', 'BB33', 'BB34', 'BB35', 'BB36']
# reading in labels for subset: BB01
# returning labelList of length: 285
# reading in images for subset: BB01
# all_image_filenames length: 285
# done current subset
# reading in labels for subset: BB02
# returning labelList of length: 45
# reading in images for subset: BB02
# all_image_filenames length: 45
# done current subset
# reading in labels for subset: BB03
# returning labelList of length: 230
# reading in images for subset: BB03
# all_image_filenames length: 230
# done current subset
# reading in labels for subset: BB04
# returning labelList of length: 999
# reading in images for subset: BB04
# all_image_filenames length: 999
# done current subset
# reading in labels for subset: BB05
# returning labelList of length: 189
# reading in images for subset: BB05
# all_image_filenames length: 189
# done current subset
# reading in labels for subset: BB06
# returning labelList of length: 1137
# reading in images for subset: BB06
# all_image_filenames length: 1137
# done current subset
# reading in labels for subset: BB07
# returning labelList of length: 324
# reading in images for subset: BB07
# all_image_filenames length: 324
# done current subset
# reading in labels for subset: BB08
# returning labelList of length: 66
# reading in images for subset: BB08
# all_image_filenames length: 66
# done current subset
# reading in labels for subset: BB09
# returning labelList of length: 357
# reading in images for subset: BB09
# all_image_filenames length: 357
# done current subset
# reading in labels for subset: BB10
# returning labelList of length: 121
# reading in images for subset: BB10
# all_image_filenames length: 121
# done current subset
# reading in labels for subset: BB11
# returning labelList of length: 167
# reading in images for subset: BB11
# all_image_filenames length: 167
# done current subset
# reading in labels for subset: BB12
# returning labelList of length: 157
# reading in images for subset: BB12
# all_image_filenames length: 157
# done current subset
# reading in labels for subset: BB13
# returning labelList of length: 50
# reading in images for subset: BB13
# all_image_filenames length: 50
# done current subset
# reading in labels for subset: BB14
# returning labelList of length: 367
# reading in images for subset: BB14
# all_image_filenames length: 367
# done current subset
# reading in labels for subset: BB15
# returning labelList of length: 91
# reading in images for subset: BB15
# all_image_filenames length: 91
# done current subset
# reading in labels for subset: BB16
# returning labelList of length: 213
# reading in images for subset: BB16
# all_image_filenames length: 213
# done current subset
# reading in labels for subset: BB17
# returning labelList of length: 26
# reading in images for subset: BB17
# all_image_filenames length: 26
# done current subset
# reading in labels for subset: BB18
# returning labelList of length: 75
# reading in images for subset: BB18
# all_image_filenames length: 75
# done current subset
# reading in labels for subset: BB19
# returning labelList of length: 72
# reading in images for subset: BB19
# all_image_filenames length: 72
# done current subset
# reading in labels for subset: BB20
# returning labelList of length: 96
# reading in images for subset: BB20
# all_image_filenames length: 96
# done current subset
# reading in labels for subset: BB21
# returning labelList of length: 78
# reading in images for subset: BB21
# all_image_filenames length: 78
# done current subset
# reading in labels for subset: BB22
# returning labelList of length: 123
# reading in images for subset: BB22
# all_image_filenames length: 123
# done current subset
# reading in labels for subset: BB23
# returning labelList of length: 192
# reading in images for subset: BB23
# all_image_filenames length: 192
# done current subset
# reading in labels for subset: BB24
# returning labelList of length: 62
# reading in images for subset: BB24
# all_image_filenames length: 62
# done current subset
# reading in labels for subset: BB25
# returning labelList of length: 10
# reading in images for subset: BB25
# all_image_filenames length: 10
# done current subset
# reading in labels for subset: BB26
# returning labelList of length: 142
# reading in images for subset: BB26
# all_image_filenames length: 142
# done current subset
# reading in labels for subset: BB27
# returning labelList of length: 46
# reading in images for subset: BB27
# all_image_filenames length: 46
# done current subset
# reading in labels for subset: BB28
# returning labelList of length: 73
# reading in images for subset: BB28
# all_image_filenames length: 73
# done current subset
# reading in labels for subset: BB29
# returning labelList of length: 20
# reading in images for subset: BB29
# all_image_filenames length: 20
# done current subset
# reading in labels for subset: BB30
# returning labelList of length: 450
# reading in images for subset: BB30
# all_image_filenames length: 450
# done current subset
# reading in labels for subset: BB31
# returning labelList of length: 42
# reading in images for subset: BB31
# all_image_filenames length: 42
# done current subset
# reading in labels for subset: BB32
# returning labelList of length: 268
# reading in images for subset: BB32
# all_image_filenames length: 268
# done current subset
# reading in labels for subset: BB33
# returning labelList of length: 136
# reading in images for subset: BB33
# all_image_filenames length: 136
# done current subset
# reading in labels for subset: BB34
# returning labelList of length: 127
# reading in images for subset: BB34
# all_image_filenames length: 127
# done current subset
# reading in labels for subset: BB35
# returning labelList of length: 45
# reading in images for subset: BB35
# all_image_filenames length: 45
# done current subset
# reading in labels for subset: BB36
# returning labelList of length: 108
# reading in images for subset: BB36
# all_image_filenames length: 108
# done current subset
# all classes (length=10): {'Empty photo', 'Cat', 'Emu', 'Kangaroo', 'Rabbit', 'Dog', 'Bird', 'Human Presense/Deployment', 'Other', 'Fox'}
# all_images size: 6989
# all_image_labels size: 6989
# training_labels length: 5591
# test_labels length: 1398
# training_classes (length=10): ['Empty photo', 'Emu', 'Human Presense/Deployment', 'Kangaroo', 'Rabbit', 'Cat', 'Bird', 'Fox', 'Other', 'Dog']
# test_classes (length=9): ['Kangaroo', 'Emu', 'Human Presense/Deployment', 'Empty photo', 'Fox', 'Rabbit', 'Cat', 'Other', 'Bird']
# training_labels length: 5591
# test_labels length: 1398
# training_classes (length=10): ['Human Presense/Deployment', 'Emu', 'Kangaroo', 'Empty photo', 'Fox', 'Rabbit', 'Cat', 'Bird', 'Other', 'Dog']
# test_classes (length=9): ['Kangaroo', 'Empty photo', 'Human Presense/Deployment', 'Emu', 'Cat', 'Fox', 'Rabbit', 'Bird', 'Other']
# training_labels length: 5591
# test_labels length: 1398
# training_classes (length=10): ['Kangaroo', 'Empty photo', 'Emu', 'Human Presense/Deployment', 'Rabbit', 'Fox', 'Bird', 'Cat', 'Other', 'Dog']
# test_classes (length=10): ['Empty photo', 'Kangaroo', 'Fox', 'Human Presense/Deployment', 'Emu', 'Cat', 'Rabbit', 'Bird', 'Other', 'Dog']
# final training_classes: ['Kangaroo', 'Empty photo', 'Emu', 'Human Presense/Deployment', 'Rabbit', 'Fox', 'Bird', 'Cat', 'Other', 'Dog']
# final test_classes: ['Empty photo', 'Kangaroo', 'Fox', 'Human Presense/Deployment', 'Emu', 'Cat', 'Rabbit', 'Bird', 'Other', 'Dog']
# all classes count: Counter({'Kangaroo': 4184, 'Empty photo': 1358, 'Emu': 614, 'Human Presense/Deployment': 523, 'Fox': 165, 'Cat': 85, 'Rabbit': 28, 'Bird': 19, 'Other': 11, 'Dog': 2})
# train classes count: Counter({'Kangaroo': 3336, 'Empty photo': 1092, 'Emu': 493, 'Human Presense/Deployment': 424, 'Fox': 129, 'Cat': 69, 'Rabbit': 21, 'Bird': 16, 'Other': 10, 'Dog': 1})
# test classes count: Counter({'Kangaroo': 848, 'Empty photo': 266, 'Emu': 121, 'Human Presense/Deployment': 99, 'Fox': 36, 'Cat': 16, 'Rabbit': 7, 'Bird': 3, 'Other': 1, 'Dog': 1})
# done stacking
# training_images shape: (5591, 224, 224, 3)
# test_images shape: (1398, 224, 224, 3)
# saving image filenames and labels in separate train/test files

# %%
class CustomGenerator(keras.utils.Sequence):    
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
    
    def __len__(self):
        return (np.ceil(len(self.images) / float(self.batch_size))).astype(np.int)

    def __getitem__(self, idx):
        batch_x = self.images[idx * self.batch_size : (idx+1) * self.batch_size]
        batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]
        
        return batch_x, np.array(batch_y)

# %%
batch_size = 128

num_len_train = int(0.8 * len(training_images))

ttraining_images = training_images[:num_len_train]
ttraining_labels = training_labels[:num_len_train]

valid_images = training_images[num_len_train:]
valid_labels = training_labels[num_len_train:]

training_images = ttraining_images
training_labels = ttraining_labels

# show a few samples
displayImage(training_images[0])
displayImage(training_images[10])
displayImage(training_images[100])
displayImage(training_images[1000])

training_batch_generator = CustomGenerator(training_images, training_labels, batch_size)
validation_batch_generator = CustomGenerator(valid_images, valid_labels, batch_size)

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
    print("Device:", tpu.master())
    strategy = tf.distribute.TPUStrategy(tpu)
except ValueError:
    print("Not connected to a TPU runtime. Using CPU/GPU strategy")
    strategy = tf.distribute.MirroredStrategy()
# Out:
# Not connected to a TPU runtime. Using CPU/GPU strategy
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# 2022-06-05 14:50:16.986313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:16.991324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:16.991498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:16.992263: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-05 14:50:16.992690: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:16.992839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:16.992973: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:17.303093: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:17.303270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:17.303410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-05 14:50:17.303531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5008 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070, pci bus id: 0000:2b:00.0, compute capability: 7.5

# %% [markdown]
# ## Train the model

# %%
IMG_SIZE = 224

# img_augmentation = Sequential(
#     [
#         layers.RandomRotation(factor=0.15),
#         layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
#         layers.RandomFlip(),
#         layers.RandomContrast(factor=0.1),
#     ],
#     name="img_augmentation",
# )

# with strategy.scope():
#     inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
#     x = img_augmentation(inputs)
#     outputs = EfficientNetB0(include_top=True, weights=None, classes=len(classes))(x)

#     model = tf.keras.Model(inputs, outputs)
#     model.compile(
#         optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"]
#     )

# model.summary()

lr = 1e-6

efficient = EfficientNetB0(include_top=True, weights=None, input_shape=(IMG_SIZE, IMG_SIZE, 3), classes=len(classes))

x = efficient.output
x = Dense(len(classes), activation='softmax')(x)
module = Model(inputs=efficient.input, outputs=x)

module.compile(optimizer=Nadam(
    lr), loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(training_batch_generator,
          validation_data=validation_batch_generator,
          epochs=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 36>()
#      31 module = Model(inputs=efficient.input, outputs=x)
#      33 module.compile(optimizer=Nadam(
#      34     lr), loss='categorical_crossentropy', metrics=['accuracy'])
# ---> 36 model.fit(training_batch_generator,
#      37           validation_data=validation_batch_generator,
#      38           epochs=40)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Use test set to assess trained model's performance

# %% [markdown]
# ### Evaluate

# %%
print('test_images shape: {}'.format(test_images.shape))
print('test_labels shape: {}'.format(test_labels.shape))

results = model.evaluate(test_images,test_labels)
print('results: {}'.format(results))

# %% [markdown]
# ### Predict and print classification report

# %%
predictions = (model.predict(test_images) > 0.5).astype("int32")

# %%
print("test_classes: {}".format(test_classes))
print("train classes count: {}".format(counter_test))
# classification_report uses alphabetic ordering of the classes, so to match the encoded labels to the target_names, provide a sortest list of classes
# https://stackoverflow.com/a/48495303
sorted_test_classes = sorted(test_classes)
print(classification_report(test_labels, predictions, target_names=sorted_test_classes))

# %% [markdown]
# ### Confusion matrix

# %%
matrix = confusion_matrix(test_labels.argmax(axis=1), predictions.argmax(axis=1))
print(matrix)

# %% [markdown]
# ### Accuracy

# %%
acc = accuracy_score(test_labels, predictions)
print(acc)

# %% [markdown]
# ## Save the model
# * use the current date/time so we can keep incrementation progress of the model as we re-run it

# %%
now = datetime.now()
dt_string = now.strftime('%d-%m-%Y_%H:%M:%S')
print("saving model as: 'InceptionV3-{}.h5'.'".format(dt_string))

model.save('saved_models/InceptionV3-{}.h5'.format(dt_string))

# %% [markdown]
# ## Free up the GPU's memory

# %%
cuda.select_device(0)
cuda.close()
